# %%
import requests
import os

API_ROOT = "https://api.synopticdata.com/v2/"
api_request_url = os.path.join(API_ROOT, "stations/latest")
API_TOKEN = '013a6e5128d740a7836b18c4eaaced93'
api_arguments = {"token": API_TOKEN, "stid": "KLAX"}

req = requests.get(api_request_url, params=api_arguments)
req.json()
# Out:
# {'STATION': [{'ID': '240',
#    'STID': 'KLAX',
#    'NAME': 'Los Angeles, Los Angeles International Airport',
#    'ELEVATION': '125.0',
#    'LATITUDE': '33.93806',
#    'LONGITUDE': '-118.38889',
#    'STATUS': 'ACTIVE',
#    'MNET_ID': '1',
#    'STATE': 'CA',
#    'TIMEZONE': 'America/Los_Angeles',
#    'ELEV_DEM': '98.4',
#    'PERIOD_OF_RECORD': {'start': '1997-04-12T00:00:00Z',
#     'end': '2024-03-18T17:35:00Z'},
#    'UNITS': {'position': 'm', 'elevation': 'ft'},
#    'OBSERVATIONS': {'altimeter_value_1': {'value': 101727.065,
#      'date_time': '2024-03-18T18:15:00Z'},
#     'air_temp_value_1': {'value': 20.0, 'date_time': '2024-03-18T18:15:00Z'},
#     'relative_humidity_value_1': {'value': 52.57,
#      'date_time': '2024-03-18T18:15:00Z'},
#     'wind_speed_value_1': {'value': 0.0, 'date_time': '2024-03-18T18:15:00Z'},
#     'wind_direction_value_1': {'value': 0.0,
#      'date_time': '2024-03-18T18:15:00Z'},
#     'wind_gust_value_1': {'value': 9.26, 'date_time': '2024-03-17T20:40:00Z'},
#     'sea_level_pressure_value_1': {'value': 101720.0,
#      'date_time': '2024-03-18T17:53:00Z'},
#     'weather_cond_code_value_1': {'value': 31.0,
#      'date_time': '2024-03-10T08:10:00Z'},
#     'cloud_layer_3_code_value_1': {'value': 2502.0,
#      'date_time': '2024-03-18T16:53:00Z'},
#     'pressure_tendency_value_1': {'value': 1.0,
#      'date_time': '2024-03-18T17:53:00Z'},
#     'precip_accum_one_hour_value_1': {'value': 0.254,
#      'date_time': '2024-03-08T02:53:00Z'},
#     'precip_accum_three_hour_value_1': {'value': 0.762,
#      'date_time': '2024-03-08T02:53:00Z'},
#     'cloud_layer_1_code_value_1': {'value': 1.0,
#      'date_time': '2024-03-18T18:15:00Z'},
#     'cloud_layer_2_code_value_1': {'value': 802.0,
#      'date_time': '2024-03-18T17:53:00Z'},
#     'precip_accum_six_hour_value_1': {'value': 0.762,
#      'date_time': '2024-03-08T05:53:00Z'},
#     'precip_accum_24_hour_value_1': {'value': 0.762,
#      'date_time': '2024-03-08T11:53:00Z'},
#     'visibility_value_1': {'value': 10.0, 'date_time': '2024-03-18T18:15:00Z'},
#     'metar_value_1': {'value': 'METAR KLAX 181815Z AUTO 00000KT 10SM CLR 20/10 A3004',
#      'date_time': '2024-03-18T18:15:00Z'},
#     'air_temp_high_6_hour_value_1': {'value': 20.0,
#      'date_time': '2024-03-18T17:53:00Z'},
#     'air_temp_low_6_hour_value_1': {'value': 10.6,
#      'date_time': '2024-03-18T17:53:00Z'},
#     'peak_wind_speed_value_1': {'value': 13.376,
#      'date_time': '2024-03-14T20:53:00Z'},
#     'ceiling_value_1': {'value': 3657.6, 'date_time': '2024-03-17T02:53:00Z'},
#     'pressure_change_code_value_1': {'value': 0.0,
#      'date_time': '2024-03-12T20:53:00Z'},
#     'air_temp_high_24_hour_value_1': {'value': 18.9,
#      'date_time': '2024-03-18T07:53:00Z'},
#     'air_temp_low_24_hour_value_1': {'value': 10.0,
#      'date_time': '2024-03-18T07:53:00Z'},
#     'peak_wind_direction_value_1': {'value': 50.0,
#      'date_time': '2024-03-14T20:53:00Z'},
#     'metar_origin_value_1': {'value': 1.0,
#      'date_time': '2024-03-18T17:53:00Z'},
#     'pressure_value_1d': {'date_time': '2024-03-18T18:15:00Z',
#      'value': 101268.13},
#     'sea_level_pressure_value_1d': {'date_time': '2024-03-18T18:15:00Z',
#      'value': 101718.55},
#     'wind_cardinal_direction_value_1d': {'date_time': '2024-03-18T18:15:00Z',
#      'value': 'N'},
#     'weather_condition_value_1d': {'date_time': '2024-03-10T08:10:00Z',
#      'value': 'mist'},
#     'weather_summary_value_1d': {'date_time': '2024-03-18T18:15:00Z',
#      'value': 'clear'},
#     'cloud_layer_1_value_1d': {'date_time': '2024-03-18T18:15:00Z',
#      'value': {'sky_condition': 'clear', 'height_agl': None}},
#     'cloud_layer_2_value_1d': {'date_time': '2024-03-18T17:53:00Z',
#      'value': {'sky_condition': 'scattered', 'height_agl': 2438.43}},
#     'cloud_layer_3_value_1d': {'date_time': '2024-03-18T16:53:00Z',
#      'value': {'sky_condition': 'scattered', 'height_agl': 7620.09}},
#     'dew_point_temperature_value_1d': {'date_time': '2024-03-18T18:15:00Z',
#      'value': 9.96}},
#    'SENSOR_VARIABLES': {'altimeter': {'altimeter_value_1': {}},
#     'air_temp': {'air_temp_value_1': {}},
#     'relative_humidity': {'relative_humidity_value_1': {}},
#     'wind_speed': {'wind_speed_value_1': {}},
#     'wind_direction': {'wind_direction_value_1': {}},
#     'wind_gust': {'wind_gust_value_1': {}},
#     'sea_level_pressure': {'sea_level_pressure_value_1': {},
#      'sea_level_pressure_value_1d': {'derived_from': ['pressure_value_1d',
#        'air_temp_value_1',
#        'relative_humidity_value_1']}},
#     'weather_cond_code': {'weather_cond_code_value_1': {}},
#     'cloud_layer_3_code': {'cloud_layer_3_code_value_1': {}},
#     'pressure_tendency': {'pressure_tendency_value_1': {}},
#     'precip_accum_one_hour': {'precip_accum_one_hour_value_1': {}},
#     'precip_accum_three_hour': {'precip_accum_three_hour_value_1': {}},
#     'cloud_layer_1_code': {'cloud_layer_1_code_value_1': {}},
#     'cloud_layer_2_code': {'cloud_layer_2_code_value_1': {}},
#     'precip_accum_six_hour': {'precip_accum_six_hour_value_1': {}},
#     'precip_accum_24_hour': {'precip_accum_24_hour_value_1': {}},
#     'visibility': {'visibility_value_1': {}},
#     'metar': {'metar_value_1': {}},
#     'air_temp_high_6_hour': {'air_temp_high_6_hour_value_1': {}},
#     'air_temp_low_6_hour': {'air_temp_low_6_hour_value_1': {}},
#     'peak_wind_speed': {'peak_wind_speed_value_1': {}},
#     'ceiling': {'ceiling_value_1': {}},
#     'pressure_change_code': {'pressure_change_code_value_1': {}},
#     'air_temp_high_24_hour': {'air_temp_high_24_hour_value_1': {}},
#     'air_temp_low_24_hour': {'air_temp_low_24_hour_value_1': {}},
#     'peak_wind_direction': {'peak_wind_direction_value_1': {}},
#     'metar_origin': {'metar_origin_value_1': {}},
#     'pressure': {'pressure_value_1d': {'derived_from': ['altimeter_value_1']}},
#     'wind_cardinal_direction': {'wind_cardinal_direction_value_1d': {'derived_from': ['wind_direction_value_1']}},
#     'weather_condition': {'weather_condition_value_1d': {'derived_from': ['weather_cond_code_value_1']}},
#     'weather_summary': {'weather_summary_value_1d': {'derived_from': ['weather_cond_code_value_1',
#        'cloud_layer_3_code_value_1',
#        'cloud_layer_2_code_value_1',
#        'cloud_layer_1_code_value_1']}},
#     'cloud_layer_1': {'cloud_layer_1_value_1d': {'derived_from': ['cloud_layer_1_code_value_1']}},
#     'cloud_layer_2': {'cloud_layer_2_value_1d': {'derived_from': ['cloud_layer_2_code_value_1']}},
#     'cloud_layer_3': {'cloud_layer_3_value_1d': {'derived_from': ['cloud_layer_3_code_value_1']}},
#     'wind_chill': {'wind_chill_value_1d': {'derived_from': ['air_temp_value_1',
#        'wind_speed_value_1']}},
#     'dew_point_temperature': {'dew_point_temperature_value_1d': {'derived_from': ['air_temp_value_1',
#        'relative_humidity_value_1']}},
#     'heat_index': {'heat_index_value_1d': {'derived_from': ['air_temp_value_1',
#        'relative_humidity_value_1']}}},
#    'QC_FLAGGED': False,
#    'RESTRICTED': False}],
#  'SUMMARY': {'NUMBER_OF_OBJECTS': 1,
#   'RESPONSE_CODE': 1,
#   'RESPONSE_MESSAGE': 'OK',
#   'METADATA_RESPONSE_TIME': '2.4 ms',
#   'QUERY_TIME': '8.7 ms',
#   'DB_QUERY_TIME': '0 ms',
#   'QC_QUERY_TIME': '0 ms',
#   'DATA_PARSING_TIME': '0.6 ms',
#   'TOTAL_DATA_TIME': '9.3 ms',
#   'VERSION': 'v2.23.3'},
#  'QC_SUMMARY': {'QC_CHECKS_APPLIED': ['sl_range_check'],
#   'TOTAL_OBSERVATIONS_FLAGGED': 0,
#   'PERCENT_OF_TOTAL_OBSERVATIONS_FLAGGED': 0.0,
#   'QC_NAMES': {'1': 'SynopticLabs Range Check'},
#   'QC_SHORTNAMES': {'1': 'sl_range_check'},
#   'QC_SOURCENAMES': {'1': 'SynopticLabs'}},
#  'UNITS': {'position': 'm',
#   'elevation': 'ft',
#   'altimeter': 'Pascals',
#   'air_temp': 'Celsius',
#   'relative_humidity': '%',
#   'wind_speed': 'm/s',
#   'wind_direction': 'Degrees',
#   'wind_gust': 'm/s',
#   'sea_level_pressure': 'Pascals',
#   'weather_cond_code': 'code',
#   'cloud_layer_3_code': 'code',
#   'pressure_tendency': 'code',
#   'precip_accum_one_hour': 'Millimeters',
#   'precip_accum_three_hour': 'Millimeters',
#   'cloud_layer_1_code': 'code',
#   'cloud_layer_2_code': 'code',
#   'precip_accum_six_hour': 'Millimeters',
#   'precip_accum_24_hour': 'Millimeters',
#   'visibility': 'Statute miles',
#   'metar': 'text',
#   'air_temp_high_6_hour': 'Celsius',
#   'air_temp_low_6_hour': 'Celsius',
#   'peak_wind_speed': 'm/s',
#   'ceiling': 'Meters',
#   'pressure_change_code': 'code',
#   'air_temp_high_24_hour': 'Celsius',
#   'air_temp_low_24_hour': 'Celsius',
#   'peak_wind_direction': 'Degrees',
#   'metar_origin': 'code',
#   'heat_index': 'Celsius',
#   'wind_chill': 'Celsius',
#   'dew_point_temperature': 'Celsius',
#   'wind_cardinal_direction': 'code',
#   'pressure': 'Pascals',
#   'weather_condition': 'code',
#   'weather_summary': 'code',
#   'cloud_layer_1': 'Meters',
#   'cloud_layer_2': 'Meters',
#   'cloud_layer_3': 'Meters'}}
