# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
salmon = xr.open_dataset('/Users/clintonalden/Documents/Research/summa_work/model/output/salmon_meadows/template_output_salmon_WY23_timestep.nc')
salmon2K = xr.open_dataset('/Users/clintonalden/Documents/Research/summa_work/model/output/salmon_meadows/template_output_salmon_+2K_WY23_timestep.nc')
sntl = pd.read_csv('/Users/clintonalden/Documents/Research/summa_work/processing/snotel_csvs/salmon_WY23.csv')
sntl['time'] = pd.to_datetime(sntl['time'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.plot(salmon.time, salmon.scalarSWE, label='summa', linestyle='--')
ax.plot(salmon2K.time, salmon2K.scalarSWE, label='summa +2K', linestyle='--')
ax.plot(sntl['time'], (sntl['SWE'])*25.4, label='obs', color='black')
ax.set_ylabel('SWE [mm]')
ax.set_title('Salmon Meadows SWE WY23')
ax.grid(ls='--', alpha=0.5)
ax.legend()
