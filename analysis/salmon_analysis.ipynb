# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
salmon = xr.open_dataset('/Users/clintonalden/Documents/Research/summa_work/model/output/salmon_meadows/template_output_salmon_WY21_timestep.nc')
sntl = pd.read_csv('/Users/clintonalden/Documents/Research/summa_work/processing/snotel_csvs/salmon_WY21.csv')
sntl['time'] = pd.to_datetime(sntl['time'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

ax.plot(salmon.time, salmon.scalarSWE, label='SWE')
ax.plot(sntl['time'], (0.3+sntl['SWE'])*25.4, label='SWE (SNTL)')
